# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyAnl7X37zwqOaRgJDhItT2dSPAN98ftcvQ")

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
def ask_agent(prompt):
    response = model.generate_content(prompt)
    return response.text

# %%
def run_agent():
    print("Welcome to the Gemini-based AI agent!")
    print("Type 'exit' to quit.\n")
    while True:
        user_input = input("You: ")
        if user_input.lower() == "exit":
            print("Agent: Goodbye!")
            break
        answer = ask_agent(user_input)
        print(f'Agent: {answer}\n')

if __name__ == "__main__":
    run_agent()
# Out:
# Welcome to the Gemini-based AI agent!
# Type 'exit' to quit.
#
# Agent: **Luster** is the way light interacts with the surface of a mineral, rock, or any other material, and how it is reflected. It's essentially a description of how shiny or brilliant a material appears.
#
# It's one of the primary physical properties used by geologists and mineralogists to identify minerals, but it applies to many other materials as well.
#
# **What Luster Describes:**
#
# 1.  **Reflectivity:** How much light is reflected from the surface.
# 2.  **Quality of Reflection:** Whether the reflection is sharp and mirror-like (specular) or scattered and diffuse (dull).
#
# **Factors Influencing Luster:**
#
# *   **Surface Roughness:** A perfectly smooth surface will produce a sharper, more mirror-like reflection (higher luster). A rough or fractured surface will scatter light, making it appear duller.
# *   **Refractive Index:** For transparent or translucent materials, a higher refractive index can contribute to a more brilliant luster because light is bent more significantly as it enters and exits the material.
# *   **Internal Absorption:** How much light is absorbed by the material versus reflected.
# *   **Chemical Composition and Structure:** The atomic structure and bonding within a material determine how light interacts with its electrons, affecting reflectivity. For example, the free electrons in metals are highly effective at reflecting light.
#
# **Main Types of Luster (with examples):**
#
# Luster is broadly divided into two main categories: **Metallic** and **Non-Metallic**.
#
# 1.  **Metallic Luster:**
#     *   Materials with metallic luster look like polished metal. They are typically opaque, highly reflective, and have a high degree of brilliance. Light doesn't penetrate the surface much; it bounces off.
#     *   **Examples:** Gold, silver, pyrite, galena, polished steel.
#
# 2.  **Non-Metallic Luster:**
#     *   This category covers a wide range of appearances that do not resemble polished metal. Light generally penetrates the surface to some extent.
#     *   **Sub-types of Non-Metallic Luster:**
#         *   **Vitreous (Glassy):** Looks like glass. It's typically transparent to translucent and reflects light brightly.
#             *   *Examples:* Quartz, calcite, feldspar, broken glass.
#         *   **Adamantine:** The brightest non-metallic luster, resembling a cut diamond. It's characterized by extremely high brilliance due to a very high refractive index.
#             *   *Examples:* Diamond, zircon, rutile.
#         *   **Resinous:** Looks like hardened tree sap or plastic. Often has a waxy or slightly oily sheen.
#             *   *Examples:* Amber, sphalerite.
#         *   **Pearly:** Iridescent, soft, and glowing, resembling a pearl or the inside of a seashell. Often seen in minerals with a layered or platy structure.
#             *   *Examples:* Muscovite (mica), talc, gypsum, natural pearls.
#         *   **Silky:** Resembles silk threads. This luster is characteristic of fibrous minerals.
#             *   *Examples:* Asbestos, fibrous gypsum, malachite (fibrous variety).
#         *   **Greasy:** Appears to be coated with a thin layer of oil or grease. Often found in minerals with many microscopic inclusions or a somewhat uneven surface.
#             *   *Examples:* Nepheline, some varieties of quartz, talc.
#         *   **Dull / Earthy:** No shine whatsoever, completely lacking in reflection. Resembles dry earth or unglazed porcelain.
#             *   *Examples:* Kaolinite, unglazed pottery, bauxite, many soil minerals.
#
# **Importance:**
#
# Luster is a crucial property for mineral identification in the field because it's often consistent for a given mineral and can be easily observed without special equipment.
#
# Agent: Goodbye!
